# %% [markdown]
# <a href="https://colab.research.google.com/github/AvinashShrivastav/Python-Programming/blob/main/TelegramBotWeek_5_Stats.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt install tesseract-ocr
# !pip install pytesseract
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# tesseract-ocr is already the newest version (4.00~git2288-10f4998a-2).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 12 not upgraded.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pytesseract in /usr/local/lib/python3.7/dist-packages (0.3.10)
# Requirement already satisfied: Pillow>=8.0.0 in /usr/local/lib/python3.7/dist-packages (from pytesseract) (9.2.0)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.7/dist-packages (from pytesseract) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=21.3->pytesseract) (3.0.9)

# %%
pip install emoji
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: emoji in /usr/local/lib/python3.7/dist-packages (2.1.0)

# %%
import pytesseract

import shutil

import os

import random
import re
import math
import emoji
import sympy as sy
from sympy import factorial, symbols,solve,Eq
try:

  from PIL import Image

except ImportError:
  import Image
from PIL import Image

# %% [markdown]
# Codes for questions

# %%
def Q1(textofimage):
  
  val = re.findall('(\d+)[^,.\d\n]+?(?=registers|cover)',textofimage)
  try:
    ques = 'Vinod has '+ str(val[0]) + ' registers and '+ str(val[1]) + ' cover papers of different colours. In how many ways can he cover all the registers with cover papers?'
    ans = (math.factorial(int(val[1]))/(math.factorial(int(val[0]))*math.factorial(int(val[1])-int(val[0]))))*math.factorial(int(val[0]))
    ans = round(ans)
  except:
    ques = emoji.emojize(":zipper-mouth_face:")
    ans = "Sorry! There was some issue while handling your file. Please try again with a different image or send #matchQ1 to get the question in text format. Surely, I would handle that."

  return ques +'\n\nAnswer : '+ str(ans) +'\nIf you think I have made any error in reading your just send #matchQ1 to get format of question in text'

Q1('Vinod has 5 registers and 8 cover papers of different colours. In how many ways can he cover all the registers with cover papers?')
# Out:
# 'Vinod has 5 registers and 8 cover papers of different colours. In how many ways can he cover all the registers with cover papers?\n\nAnswer : 6720\nIf you think I have made any error in reading your just send #matchQ1 to get format of question in text'

# %%
def Q11(textofimage):
  
  ques = 'Vinod has 5 registers and 8 cover papers of different colours. In how many ways can he cover all the registers with cover papers?'
  ans = "Please copy the message as it is and just replace the values according to your question #solveQ1 "

  return ques +'  \n\n'+ str(ans)

# %%
def Q2(textofimage):
  val = re.findall('(\d+)[^,.\d\n]+?(?=classmates)',textofimage)
  try:
    ques = str(val[0]) + ' classmates could not agree on who would stand in the group photo along with the teacher for the yearbook. How many possible groups can be made such that there is at least one student with the teacher in the photo?'
    ans = pow(2,int(val[0])) - 1
  except:
    ques = emoji.emojize(":zipper-mouth_face:")
    ans = "Sorry! There was some issue while handling your file. Please try again with a different image or send #matchQ2 to get the question in text format. Surely, I would handle that."

  return ques +'\n\nAnswer : '+ str(ans)+'\nIf you think I have made any error in reading your just send #matchQ2 to get format of question in text'

# %%
def Q21(textofimage):
  
  ques = '6 classmates could not agree on who would stand in the group photo along with the teacher for the yearbook. How many possible groups can be made such that there is at least one student with the teacher in the photo?'
  ans = "Please copy the message as it is and just replace the values according to your question #solveQ2 "

  return ques +'  \n\n'+ str(ans)

# %%
def Q3(textofimage):
  
  try:
    val = re.findall('(\d+)[^,.\d\n]+?(?=alphabets|numbers)',textofimage)
    ques = 'Jay bought a new car in New York where a license plate can be created with alphabets A, B, C, D, E, W, X, Y, Z and numbers 0 to 9. He can either select a normal license plate or a VIP license plate. The VIP license plate begins with ' +str(val[0])+' alphabets followed by ' +str(val[1])+' numbers with repetition allowed. The normal license plate begins with ' +str(val[2])+' numbers followed by ' +str(val[3])+' alphabets without repetition.In how many ways can he select VIP license plate?'
    ans =  pow(9,int(val[0]))*pow(10,int(val[1]))
  except:
    ques = emoji.emojize(":zipper-mouth_face:")
    ans = "Sorry! There was some issue while handling your file. Please try again with a different image or send #matchQ3 to get the question in text format. Surely, I would handle that. \nPreferred image: set of allowed alphabets should be in a line."

  return  ques + '\n\nAnswer : '+ str(ans)+'\nIf you think I have made any error in reading your just send #matchQ3 to get format of question in text'


q='''Jay bought a new car in New York where a license plate can be created with alphabets A, B, C, D, E, W, X, Y, Z and numbers 0 to 9. He can either select a normal license plate or a VIP license plate. The VIP license plate begins with 2 alphabets followed by 4 numbers with repetition allowed. The normal license plate begins with 2 numbers followed by 3 alphabets without repetition.In how many ways can he select VIP license plate?'''
Q3(q)
# Out:
# 'Jay bought a new car in New York where a license plate can be created with alphabets A, B, C, D, E, W, X, Y, Z and numbers 0 to 9. He can either select a normal license plate or a VIP license plate. The VIP license plate begins with 2 alphabets followed by 4 numbers with repetition allowed. The normal license plate begins with 2 numbers followed by 3 alphabets without repetition.In how many ways can he select VIP license plate?\n\nAnswer : 810000\nIf you think I have made any error in reading your just send #matchQ3 to get format of question in text'

# %%
def Q31(textofimage):
  
  ques = 'Jay bought a new car in New York where a license plate can be created with alphabets A, B, C, D, E, W, X, Y, Z and numbers 0 to 9. He can either select a normal license plate or a VIP license plate. The VIP license plate begins with 1 alphabets followed by 2 numbers with repetition allowed. The normal license plate begins with 1 numbers followed by 2 alphabets without repetition.In how many ways can he select VIP license plate?'
  ans = "Please copy the message as it is and just replace the values according to your question #solveQ3 "

  return ques +'  \n\n'+ str(ans)

# %%
def Q4(textofimage):
  
  try:
    val = re.findall('(\d+)[^,.\d\n]+?(?=alphabets|numbers)',textofimage)
    ques = 'Jay bought a new car in New York where a license plate can be created with alphabets A, B, C, D, E, W, X, Y, Z and numbers 0 to 9. He can either select a normal license plate or a VIP license plate. The VIP license plate begins with ' +str(val[0])+' alphabets followed by ' +str(val[1])+' numbers with repetition allowed. The normal license plate begins with ' +str(val[2])+' numbers followed by ' +str(val[3])+' alphabets without repetition.In how many ways can he select VIP license plate?'
    ans1 =  pow(9,int(val[0]))*pow(10,int(val[1]))
    ans2 = (factorial(10)*factorial(9))/((factorial(10-int(val[2]))*factorial(9-int(val[3]))))
  # ans2= ((factorial(10)*factorial(int(val[3])))/(factorial(int(val[3]))*factorial(10-int(val[3]))))*((factorial(n1)*factorial(int(val[4])))/(factorial(int(val[4]))*factorial(n1-int(val[4]))))
    ans = str(ans1+ans2) + "\nNote: we have considered that the first digit of a number plate may be 0. "
  except:
    ques = emoji.emojize(":zipper-mouth_face:")
    ans = "Sorry! There was some issue while handling your file. Please try again with a different image or send #matchQ4 to get the question in text format. Surely, I would handle that. \nPreferred image: set of allowed alphabets should be in a line."

  return  ques + '\n\nAnswer : '+ str(ans)+'\nIf you think I have made any error in reading your just send #matchQ4 to get format of question in text'


q='''Jay bought a new car in New York where a license plate can be created with alphabets A, B, C, D, E, W, X, Y, Z and numbers 0 to 9. He can either select a normal license plate or a VIP license plate. The VIP license plate begins with 2 alphabets followed by 4 numbers with repetition allowed. The normal license plate begins with 2 numbers followed by 3 alphabets without repetition.In how many ways can he select VIP license plate?'''
Q4(q)
# Out:
# 'Jay bought a new car in New York where a license plate can be created with alphabets A, B, C, D, E, W, X, Y, Z and numbers 0 to 9. He can either select a normal license plate or a VIP license plate. The VIP license plate begins with 2 alphabets followed by 4 numbers with repetition allowed. The normal license plate begins with 2 numbers followed by 3 alphabets without repetition.In how many ways can he select VIP license plate?\n\nAnswer : 855360\nNote: we have considered that the first digit of a number plate may be 0. \nIf you think I have made any error in reading your just send #matchQ4 to get format of question in text'

# %%
def Q41(textofimage):
  
  ques = 'Jay bought a new car in New York where a license plate can be created with alphabets A, B, C, D, E, W, X, Y, Z and numbers 0 to 9. He can either select a normal license plate or a VIP license plate. The VIP license plate begins with 1 alphabets followed by 2 numbers with repetition allowed. The normal license plate begins with 1 numbers followed by 2 alphabets without repetition.In how many ways can he select VIP license plate?'
  ans = "Please copy the message as it is and just replace the values according to your question #solveQ4 "

  return ques +'  \n\n'+ str(ans)

# %%
def Q5(textofimage):
  import sympy
  val2 = re.findall('(\d+)[^,.\d\n]+?(?=times)',textofimage)
  val1 = re.findall("by\s*(-?\d+(?:\.\d+)?)",textofimage)
 
  try:
    val = [val1[0],val2[0]]
    n = symbols('n')
    lhs= n*(n-1)*int(val[1])
    rhs = (n+int(val[0]))*(n+int(val[0])-1)
    ans1 = solve(Eq(lhs,rhs))
    for i in ans1:
      if i>0:
        ans=i
      else :
        ans = "Calculation Failed!"

    ques = 'Ram has n trophies that he wishes to place in his main cabinet, which has space only for two trophies. If the number of trophies is increased by '+ str(val[0])+ ', then the number of possible ways to arrange the trophies in the main cabinet becomes '+str(val[1])+' times the number of ways to arrange n trophies. How many trophies does Ram have?'
  except:
    ques = emoji.emojize(":zipper-mouth_face:")
    ans = "Sorry! There was some issue while handling your file. Please try again with a different image or send #matchQ5 to get the question in text format. Surely, I would handle that."

  return ques +'\n\nAnswer : '+ str(ans) +'\nIf you think I have made any error in reading your just send #matchQ5 to get format of question in text'
Q5('5) Ram has n trophies that he wishes to place in his main cabinet, which has space only for two trophies. If the number of trophies is increased by 3, then the number of possible ways to arrange the trophies in the main cabinet becomes 5 times the number of ways to arrange n trophies. How many trophies does Ram have?')
# Out:
# 'Ram has n trophies that he wishes to place in his main cabinet, which has space only for two trophies. If the number of trophies is increased by 3, then the number of possible ways to arrange the trophies in the main cabinet becomes 5 times the number of ways to arrange n trophies. How many trophies does Ram have?\n\nAnswer : 3\nIf you think I have made any error in reading your just send #matchQ5 to get format of question in text'

# %%
def Q51(textofimage):
  
  ques = 'Ram has n trophies that he wishes to place in his main cabinet, which has space only for two trophies. If the number of trophies is increased by 3, then the number of possible ways to arrange the trophies in the main cabinet becomes 5 times the number of ways to arrange n trophies. How many trophies does Ram have?'
  ans = "Please copy the message as it is and just replace the values according to your question #solveQ5 "

  return ques +'  \n\n'+ str(ans)

# %%
def Q52(textofimage):
  import sympy
  val = re.findall("[2-9]",textofimage)
  try:
    # val=[3,5]
    n = symbols('n')
    lhs= n*(n-1)*int(val[1])
    rhs = (n+int(val[0]))*(n+int(val[0])-1)
    ans1 = solve(Eq(lhs,rhs))
    for i in ans1:
      if i>0:
        ans=i
      else :
        ans = "Calculation Failed!"

    ques = 'Ram has n trophies that he wishes to place in his main cabinet, which has space only for two trophies. If the number of trophies is increased by '+ str(val[0])+ ', then the number of possible ways to arrange the trophies in the main cabinet becomes '+str(val[1])+' times the number of ways to arrange n trophies. How many trophies does Ram have?'
  except:
    ques = emoji.emojize(":zipper-mouth_face:")
    ans = "Sorry! There was some issue while handling your file. Please try again"

  return ques +'\n\nAnswer : '+ str(ans)
Q52('Ram has n trophies that he wishes to place in his main cabinet, which has space only for two trophies. If the number of trophies is increased by 3, then the number of possible ways to arrange the trophies in the main cabinet becomes 5 times the number of ways to arrange n trophies. How many trophies does Ram have?')
# Out:
# 'Ram has n trophies that he wishes to place in his main cabinet, which has space only for two trophies. If the number of trophies is increased by 3, then the number of possible ways to arrange the trophies in the main cabinet becomes 5 times the number of ways to arrange n trophies. How many trophies does Ram have?\n\nAnswer : 3'

# %%
def Q6(textofimage):
  val1 = re.findall('(\d+)[^,.\d\n]+?(?=students)',textofimage)
  val2 = re.findall("first\s*(-?\d+(?:\.\d+)?)",textofimage)
  
  try:
    val = [val1[0],val2[0]]
    ques = 'There are '+str(val[0])+' students in a class. The class teacher announced that the first  '+str(val[1])+' students who completes a given project within two days will be awarded. What are the possible number of ways the students will be awarded?'
    ans = (factorial(int(val[0])))/(factorial(int(val[1]))*factorial(int(val[0])-int(val[1])))
    text = str(val[0])+'!/('+str((int(val[0])-int(val[1])))+'! x '+str(val[1])+'!)'
  except:
    ques = emoji.emojize(":zipper-mouth_face:")
    ans = "Sorry! There was some issue while handling your file. Please try again with a different image or send #matchQ6 to get the question in text format. Surely, I would handle that."
    text = ''
  return ques +'\n\nAnswer : '+ text + '='+ str(ans)+'\nIf you think I have made any error in reading your just send #matchQ6 to get format of question in text'
Q6('There are 40 students in a class. The class teacher announced that the first  5 students who completes a given project within two days will be awarded. What are the possible number of ways the students will be awarded?')
# Out:
# 'There are 40 students in a class. The class teacher announced that the first  5 students who completes a given project within two days will be awarded. What are the possible number of ways the students will be awarded?\n\nAnswer : 40!/(35! x 5!)=658008\nIf you think I have made any error in reading your just send #matchQ6 to get format of question in text'

# %%
def Q61(textofimage):
  
  ques = 'There are 30 students in a class. The class teacher announced that the first  4 students who completes a given project within two days will be awarded. What are the possible number of ways the students will be awarded?'
  ans = "Please copy the message as it is and replace the values according to your question and send #solveQ6 "

  return ques +'  \n\n'+ str(ans)

# %%
def Q7(textofimage):
  val = re.findall('(\d+)[^,.\d\n]+?(?=students)',textofimage)
  try:
    ques = val[0]+' students watched a patriotic movie. An analyst wishes to ask each student whether they liked the movie or not. Each student can either answer the question or refuse to respond. In how many ways, can the analyst get responses from the students?'
    ans = pow(3,int(val[0]))
  except:
    ques = emoji.emojize(":zipper-mouth_face:")
    ans = "Sorry! There was some issue while handling your file. Please try again with a different image or send #matchQ7 to get the question in text format. Surely, I would handle that."

  return ques +' Answer : '+ str(ans)+'\nIf you think I have made any error in reading your just send #matchQ7 to get format of question in text'

# %%
def Q71(textofimage):
  
  ques = '7 students watched a patriotic movie. An analyst wishes to ask each student whether they liked the movie or not. Each student can either answer the question or refuse to respond. In how many ways, can the analyst get responses from the students?'
  ans = "Please copy the message as it is and replace the values according to your question and send #solveQ7 "

  return ques +'  \n\n'+ str(ans)

# %%
def Q8(textofimage):
  val = re.findall('(\d+)[^,.\d\n]+?(?=non)',textofimage)
  try:
    ques = 'If the value of sum of first '+str(val[0])+' non-zero natural numbers is equal to {} , then find the value of 1/{}?'
    ans = "Sorry! I could'nt extract data from the image. You may retry or send #matchQ8 to get the question in text format. Surely, I would handle that."
  except:
    ques = emoji.emojize(":zipper-mouth_face:")
    ans = "Sorry! There was some issue while handling your file. Please try again with a different image "

  return ques +'\n\nAnswer : \n\n'+ str(ans)

# %%
def Q82(textofimage):
  
  ques = 'If the value of sum of first 5 non-zero natural numbers is equal to factorial(6)x/4 then find the value of 1/x?'
  ans = "Please copy the message as it is and just replace the values according to your question #solveQ8 "

  return ques +'  \n\n'+ str(ans)

# %%
def Q83(textofimage):
  val = re.findall('(\d+)[^,.\d\n]+?(?=non|x|then)',textofimage)
  try:
    ques = 'If the value of sum of first '+str(val[0])+' non-zero natural numbers is equal to '+str(val[1])+'!x/'+str(val[2])+' , then find the value of 1/x?'
    ans = (factorial(int(val[1]))*2)/(int(val[2])*int(val[0])*(int(val[0])+1))
  except:
    ques = emoji.emojize(":zipper-mouth_face:")
    ans = "Sorry! There was some issue while handling your file. Please try again with a different image"
  return ques +' \n\nAnswer: '+ str(ans)

# %%
def Q9(textofimage):
  val = re.findall('(\d+)[^,.\d\n]+?(?=digit)',textofimage)
  try:
    ques = 'Adam wrote down a '+str(val[0])+'-digit university roll number on a piece of paper. On his way home from office, it rained heavily and the paper got wet. Later, he saw that the first '+str(val[1])+' digits of the roll number had disappeared. In how many ways can Adam complete this university roll number if repetition of digits is allowed?'
    ans = pow(10,int(val[1]))
  except:
    ques = emoji.emojize(":zipper-mouth_face:")
    ans = "Sorry! There was some issue while handling your file. Please try again with a different image or send #matchQ9 to get the question in text format. Surely, I would handle that."

  return ques +' Answer : '+ str(ans)+'\nIf you think I have made any error in reading your just send #matchQ9 to get format of question in text'

# %%
def Q91(textofimage):
  
  ques = 'Adam wrote down a 12-digit university roll number on a piece of paper. On his way home from office, it rained heavily and the paper got wet. Later, he saw that the first 4 digits of the roll number had disappeared. In how many ways can Adam complete this university roll number if repetition of digits is allowed?'
  ans = "Please copy the message as it is and just replace the values according to your question #solveQ9 "

  return ques +'  \n\n'+ str(ans)

# %%
def Q10(textofimage):
  try:
    ques = 'Let x = factorial({})/{}xfactorial({}).Which of the following expressions is/are equal to x?'
    ans ="Sorry! I could'nt extract data from the image. You may retry or send #matchQ10 to get the question in text format. Surely, I would handle that."

  except:
    ques = emoji.emojize(":zipper-mouth_face:")
    ans = "Sorry! There was some issue while handling your file. Please try again with a different image"

  return ques +'\n\nAnswer : '+ str(ans)+'\nIf you think I have made any error in reading your just send #matchQ<your question number> to get format of question in text'

# %%
def Q102(textofimage):
  
  ques = 'Let x = 5!/4x3!.Which of the following expressions is/are equal to x?'
  ans = "Please copy the message as it is and replace the values according to your question and send #solveQ10 "

  return ques +'  \n\n'+ str(ans)

# %%
def Q103(textofimage):
  val = re.findall("[2-9]",textofimage)
  try:
    ques = 'Let x ='+str(val[0])+'!/'+str(val[1])+'x'+str(val[2])+'! .Which of the following expressions is/are equal to x?'
    ans = factorial(int(val[0]))/(int(val[1])*factorial(int(val[2])))

  except:
    ques = emoji.emojize(":zipper-mouth_face:")
    ans = "Sorry! There was some issue while handling your file. Please try again with a different image"

  return ques +'\n\nAnswer : '+ str(ans)+'\nIf you think I have made any error in reading your just send #matchQ10 to get format of question in text'

# %%
import requests
import pytesseract
import urllib.request
from PIL import Image
import PIL
from pathlib import Path
from PIL import UnidentifiedImageError
import numpy as np
base_url = "https://api.telegram.org/bot5790152486:AAFlWLsa1NLe92uNLHdmGJq2ifyQB19OtQY"
token = '5790152486:AAFlWLsa1NLe92uNLHdmGJq2ifyQB19OtQY'





def read_msg(offset):
  parameters = {
      "offset" :offset

  }

  resp = requests.get(base_url + "/getUpdates", data = parameters)
  
  data = resp.json()

  print(data)


  for result in data["result"]:

    if "edited_message" in result.keys():
      if "text" in result["edited_message"].keys():
        if "#mathmatch" in result["edited_message"]["text"]:
          Q1ans = "Sorry! I cannot reply to edited message. You may try resending it"
          send_msg(result,Q1ans)
    if "message" in result.keys():
      if "text" in result["message"].keys():

        if '#matchQ8' in result["message"]['text']:
          ans = Q82(result["message"]['text'])
          send_msg(result, ans)
          if data["result"]:
            return data["result"][-1]["update_id"] + 1
        elif '#solveQ8' in result["message"]['text']:
          ans = Q83(result["message"]['text'])
          send_msg(result, ans)
          if data["result"]:
            return data["result"][-1]["update_id"] + 1
        elif '#matchQ10' in result["message"]['text']:
          ans = Q102(result["message"]['text'])
          send_msg(result, ans)
          if data["result"]:
            return data["result"][-1]["update_id"] + 1
        elif '#solveQ10' in result["message"]['text']:
          ans = Q103(result["message"]['text'])
          send_msg(result, ans)
          if data["result"]:
            return data["result"][-1]["update_id"] + 1
        
        elif '#matchQ1' in result["message"]['text']:
          ans = Q11(result["message"]['text'])
          send_msg(result, ans)
          if data["result"]:
            return data["result"][-1]["update_id"] + 1
        elif '#solveQ1' in result["message"]['text']:
          ans = Q1(result["message"]['text'])
          send_msg(result, ans)
          if data["result"]:
            return data["result"][-1]["update_id"] + 1

        elif '#matchQ2' in result["message"]['text']:
          ans = Q21(result["message"]['text'])
          send_msg(result, ans)
          if data["result"]:
            return data["result"][-1]["update_id"] + 1
        elif '#solveQ2' in result["message"]['text']:
          ans = Q2(result["message"]['text'])
          send_msg(result, ans)
          if data["result"]:
            return data["result"][-1]["update_id"] + 1

        elif '#matchQ3' in result["message"]['text']:
          ans = Q31(result["message"]['text'])
          send_msg(result, ans)
          if data["result"]:
            return data["result"][-1]["update_id"] + 1
        elif '#solveQ3' in result["message"]['text']:
          ans = Q3(result["message"]['text'])
          send_msg(result, ans)
          if data["result"]:
            return data["result"][-1]["update_id"] + 1

        elif '#matchQ4' in result["message"]['text']:
          ans = Q41(result["message"]['text'])
          send_msg(result, ans)
          if data["result"]:
            return data["result"][-1]["update_id"] + 1
        elif '#solveQ4' in result["message"]['text']:
          ans = Q4(result["message"]['text'])
          send_msg(result, ans)
          if data["result"]:
            return data["result"][-1]["update_id"] + 1


        elif '#matchQ5' in result["message"]['text']:
          ans = Q51(result["message"]['text'])
          send_msg(result, ans)
          if data["result"]:
            return data["result"][-1]["update_id"] + 1
        elif '#solveQ5' in result["message"]['text']:
          ans = Q5(result["message"]['text'])
          send_msg(result, ans)
          if data["result"]:
            return data["result"][-1]["update_id"] + 1

        elif '#matchQ6' in result["message"]['text']:
          ans = Q61(result["message"]['text'])
          send_msg(result, ans)
          if data["result"]:
            return data["result"][-1]["update_id"] + 1
        elif '#solveQ6' in result["message"]['text']:
          ans = Q6(result["message"]['text'])
          send_msg(result, ans)
          if data["result"]:
            return data["result"][-1]["update_id"] + 1

        elif '#matchQ7' in result["message"]['text']:
          ans = Q71(result["message"]['text'])
          send_msg(result, ans)
          if data["result"]:
            return data["result"][-1]["update_id"] + 1
        elif '#solveQ7' in result["message"]['text']:
          ans = Q7(result["message"]['text'])
          send_msg(result, ans)
          if data["result"]:
            return data["result"][-1]["update_id"] + 1

        elif '#matchQ9' in result["message"]['text']:
          ans = Q91(result["message"]['text'])
          send_msg(result, ans)
          if data["result"]:
            return data["result"][-1]["update_id"] + 1
        elif '#solveQ9' in result["message"]['text']:
          ans = Q9(result["message"]['text'])
          send_msg(result, ans)
          if data["result"]:
            return data["result"][-1]["update_id"] + 1


           # "______________________________________________________________"

        if data["result"]:
          return data["result"][-1]["update_id"] + 1
      # elif "photo" in result["message"]:
        
      #   file_id = result["message"]['photo'][-1]['file_id']
      #   getFile = requests.get(base_url+"/getFile?file_id="+file_id).json()
      #   file_path = getFile["result"]['file_path']
      #   photo_url = 'https://api.telegram.org/file/bot'+token+'/'+file_path
      #   print(photo_url)
      #   urllib.request.urlretrieve(photo_url,"image.png")
      #   img = Image.open('image.png')
      #   textofimage = pytesseract.image_to_string(img)
      
      #   '---------------------------------------------------------------------------'
      #   #Navigating to questions:

      #   if 'Let' in textofimage:
      #     ans = Q10(textofimage)
      #     send_msg(result, ans)
      #     if data["result"]:
      #       return data["result"][-1]["update_id"] + 1

      #   elif '1)' in textofimage or 'Vinod' in textofimage:
      #     ans = Q1(textofimage)
      #     send_msg(result, ans)
      #     if data["result"]:
      #       return data["result"][-1]["update_id"] + 1
        
      #   elif '2)' in textofimage or 'classmates' in textofimage:
      #     ans = Q2(textofimage)
      #     send_msg(result, ans)
      #     if data["result"]:
      #       return data["result"][-1]["update_id"] + 1

      #   elif '3)' in textofimage:
      #     ans = Q3(textofimage)
      #     send_msg(result, ans)
      #     if data["result"]:
      #       return data["result"][-1]["update_id"] + 1

      #   elif '4)' in textofimage:
      #     ans = Q4(textofimage)
      #     send_msg(result, ans)
      #     if data["result"]:
      #       return data["result"][-1]["update_id"] + 1

      #   elif '5)' in textofimage or 'Ram' in textofimage:
      #     ans = Q5(textofimage)
      #     send_msg(result, ans)
      #     if data["result"]:
      #       return data["result"][-1]["update_id"] + 1

      #   elif '6)' in textofimage or 'awarded' in textofimage:
      #     ans = Q6(textofimage)
      #     send_msg(result, ans)
      #     if data["result"]:
      #       return data["result"][-1]["update_id"] + 1

      #   elif '7)' in textofimage or 'movie' in textofimage:
      #     ans = Q7(textofimage)
      #     send_msg(result, ans)
      #     if data["result"]:
      #       return data["result"][-1]["update_id"] + 1

      #   elif '8)' in textofimage or 'natural' in textofimage:
      #     ans = Q8(textofimage)
      #     send_msg(result, ans)
      #     if data["result"]:
      #       return data["result"][-1]["update_id"] + 1

      #   elif '9)' in textofimage or 'Adam' in textofimage:
      #     ans = Q9(textofimage)
      #     send_msg(result, ans)
      #     if data["result"]:
      #       return data["result"][-1]["update_id"] + 1

        

      #   else:
      #     ans = "Could'nt Process Your Data! Please try again "
      #     send_msg(result, ans)
      #     if data["result"]:
      #       return data["result"][-1]["update_id"] + 1

    if data["result"]:
          return data["result"][-1]["update_id"] + 1


      
      

def send_msg(message,num):
  try:
    msg_id = message["message"]["message_id"]
    name = message["message"]["from"]["first_name"]
    chat_id = message["message"]["chat"]["id"]

    if (message["message"]["chat"]["type"]=="private"):

      parameters = {
          "chat_id" : chat_id,
          "text" : "Sorry! But I am not suppose to reply you back in private. Follow this link to join your friends and ask your question : https://t.me/+VmDY-E-Q6Pg5ZTVl ",
          "reply_to_message_id" : msg_id
      }
      resp = requests.get(base_url + "/sendMessage", data = parameters)
    else:
      parameters = {
          "chat_id" : chat_id,
          "text" :"Here it is : \n"+ num + "\n\nAnswer Matching? Thumbs up! or Not Matching? Thumbs down!",
          "reply_to_message_id" : msg_id
      }
      resp = requests.get(base_url + "/sendMessage", data = parameters)
  except:
    chat_id = message["message"]["chat"]["id"]
    parameters = {
        
        "chat_id" :chat_id,
        "text" : "It seems there is some problem! Try Again.",
        "reply_to_message_id" : msg_id
    }
    resp = requests.get(base_url + "/sendMessage", data = parameters)
    print(resp.text)

# def user
# resp = requests.get(base_url + "/User", data = parameters)

offset = 0

while True:

  offset = read_msg(offset)
# Out:
# {'ok': True, 'result': [{'update_id': 182987366, 'message': {'message_id': 271, 'from': {'id': 1422299869, 'is_bot': False, 'first_name': 'Avinash', 'last_name': 'Shrivastava', 'username': 'avishrivastava', 'language_code': 'en'}, 'chat': {'id': -1001763475425, 'title': 'IITM Buddy', 'type': 'supergroup'}, 'date': 1665594496, 'photo': [{'file_id': 'AgACAgUAAx0CaRx_4QACAQ9jRvSAxhEKeoXYJ4pWEkqqiNIgVQACZbMxG3YUOFbmLAgRob-mgwEAAwIAA3MAAyoE', 'file_unique_id': 'AQADZbMxG3YUOFZ4', 'file_size': 1217, 'width': 90, 'height': 62}, {'file_id': 'AgACAgUAAx0CaRx_4QACAQ9jRvSAxhEKeoXYJ4pWEkqqiNIgVQACZbMxG3YUOFbmLAgRob-mgwEAAwIAA20AAyoE', 'file_unique_id': 'AQADZbMxG3YUOFZy', 'file_size': 19237, 'width': 320, 'height': 222}, {'file_id': 'AgACAgUAAx0CaRx_4QACAQ9jRvSAxhEKeoXYJ4pWEkqqiNIgVQACZbMxG3YUOFbmLAgRob-mgwEAAwIAA3gAAyoE', 'file_unique_id': 'AQADZbMxG3YUOFZ9', 'file_size': 49345, 'width': 720, 'height': 500}]}}, {'update_id': 182987367, 'message': {'message_id': 5191, 'from': {'id': 1301271215, 'is_bot': False, 'first_name': 'SU€ZY:)', 'username': 'mujhsematpuchona', 'language_code': 'en'}, 'chat': {'id': -1001636347521, 'title': 'Challenge Answer', 'type': 'supergroup'}, 'date': 1665594524, 'photo': [{'file_id': 'AgACAgUAAx0CYYiugQACFEdjRvScnFbZzNe4MQwBUpLAIt8RUAAC6rMxGx_xMFaBD-tmnAtGEAEAAwIAA3MAAyoE', 'file_unique_id': 'AQAD6rMxGx_xMFZ4', 'file_size': 1105, 'width': 90, 'height': 53}, {'file_id': 'AgACAgUAAx0CYYiugQACFEdjRvScnFbZzNe4MQwBUpLAIt8RUAAC6rMxGx_xMFaBD-tmnAtGEAEAAwIAA20AAyoE', 'file_unique_id': 'AQAD6rMxGx_xMFZy', 'file_size': 17601, 'width': 320, 'height': 187}, {'file_id': 'AgACAgUAAx0CYYiugQACFEdjRvScnFbZzNe4MQwBUpLAIt8RUAAC6rMxGx_xMFaBD-tmnAtGEAEAAwIAA3gAAyoE', 'file_unique_id': 'AQAD6rMxGx_xMFZ9', 'file_size': 54890, 'width': 800, 'height': 468}, {'file_id': 'AgACAgUAAx0CYYiugQACFEdjRvScnFbZzNe4MQwBUpLAIt8RUAAC6rMxGx_xMFaBD-tmnAtGEAEAAwIAA3kAAyoE', 'file_unique_id': 'AQAD6rMxGx_xMFZ-', 'file_size': 71380, 'width': 1080, 'height': 632}]}}, {'update_id': 182987368, 'message': {'message_id': 5192, 'from': {'id': 1361861524, 'is_bot': False, 'first_name': 'Saad', 'last_name': 'Chavhan', 'username': 'Saadchavhan9'}, 'chat': {'id': -1001636347521, 'title': 'Challenge Answer', 'type': 'supergroup'}, 'date': 1665594632, 'document': {'file_name': 'STATS ANS.pdf', 'mime_type': 'application/pdf', 'thumb': {'file_id': 'AAMCBQADHQJhiK6BAAIUSGNG9Qk9ELLGHXwy7HIWoR1Yo63aAALOBgACH_EwVm7y713xGa0vAQAHbQADKgQ', 'file_unique_id': 'AQADzgYAAh_xMFZy', 'file_size': 16927, 'width': 247, 'height': 320}, 'file_id': 'BQACAgUAAx0CYYiugQACFEhjRvUJPRCyxh18MuxyFqEdWKOt2gACzgYAAh_xMFZu8u9d8RmtLyoE', 'file_unique_id': 'AgADzgYAAh_xMFY', 'file_size': 256426}}}, {'update_id': 182987369, 'message': {'message_id': 5193, 'from': {'id': 2009150623, 'is_bot': False, 'first_name': 'Cricketer', 'last_name': 'Aman'}, 'chat': {'id': -1001636347521, 'title': 'Challenge Answer', 'type': 'supergroup'}, 'date': 1665594687, 'photo': [{'file_id': 'AgACAgUAAx0CYYiugQACFEljRvU_svCRLZe9p1hLFeQvrrgPQQAC67MxGx_xMFbOccLjJvyo0QEAAwIAA3MAAyoE', 'file_unique_id': 'AQAD67MxGx_xMFZ4', 'file_size': 420, 'width': 90, 'height': 12}, {'file_id': 'AgACAgUAAx0CYYiugQACFEljRvU_svCRLZe9p1hLFeQvrrgPQQAC67MxGx_xMFbOccLjJvyo0QEAAwIAA20AAyoE', 'file_unique_id': 'AQAD67MxGx_xMFZy', 'file_size': 4180, 'width': 320, 'height': 44}, {'file_id': 'AgACAgUAAx0CYYiugQACFEljRvU_svCRLZe9p1hLFeQvrrgPQQAC67MxGx_xMFbOccLjJvyo0QEAAwIAA3gAAyoE', 'file_unique_id': 'AQAD67MxGx_xMFZ9', 'file_size': 21240, 'width': 800, 'height': 111}, {'file_id': 'AgACAgUAAx0CYYiugQACFEljRvU_svCRLZe9p1hLFeQvrrgPQQAC67MxGx_xMFbOccLjJvyo0QEAAwIAA3kAAyoE', 'file_unique_id': 'AQAD67MxGx_xMFZ-', 'file_size': 50773, 'width': 1280, 'height': 178}]}}, {'update_id': 182987370, 'message': {'message_id': 5194, 'from': {'id': 5783319568, 'is_bot': False, 'first_name': 'Ciri🍁'}, 'chat': {'id': -1001636347521, 'title': 'Challenge Answer', 'type': 'supergroup'}, 'date': 1665594795, 'photo': [{'file_id': 'AgACAgUAAx0CYYiugQACFEpjRvWs9ZRNd4-qAAH6 ...
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': [{'update_id': 182987376, 'message': {'message_id': 272, 'from': {'id': 1422299869, 'is_bot': False, 'first_name': 'Avinash', 'last_name': 'Shrivastava', 'username': 'avishrivastava', 'language_code': 'en'}, 'chat': {'id': -1001763475425, 'title': 'IITM Buddy', 'type': 'supergroup'}, 'date': 1665595411, 'text': '#matchQ3', 'entities': [{'offset': 0, 'length': 8, 'type': 'hashtag'}]}}]}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': [{'update_id': 182987377, 'message': {'message_id': 274, 'from': {'id': 1422299869, 'is_bot': False, 'first_name': 'Avinash', 'last_name': 'Shrivastava', 'username': 'avishrivastava', 'language_code': 'en'}, 'chat': {'id': -1001763475425, 'title': 'IITM Buddy', 'type': 'supergroup'}, 'date': 1665595421, 'text': 'Here it is : \nJay bought a new car in New York where a license plate can be created with alphabets A, B, C, D, E, W, X, Y, Z and numbers 0 to 9. He can either select a normal license plate or a VIP license plate. The VIP license plate begins with 1 alphabets followed by 2 numbers with repetition allowed. The normal license plate begins with 1 numbers followed by 2 alphabets without repetition.In how many ways can he select VIP license plate?  \n\nPlease copy the message as it is and just replace the values according to your question #solveQ3 \n\nAnswer Matching? Thumbs up! or Not Matching? Thumbs down!', 'entities': [{'offset': 537, 'length': 8, 'type': 'hashtag'}]}}]}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': [{'update_id': 182987378, 'edited_message': {'message_id': 5198, 'from': {'id': 1422299869, 'is_bot': False, 'first_name': 'Avinash', 'last_name': 'Shrivastava', 'username': 'avishrivastava', 'language_code': 'en'}, 'chat': {'id': -1001636347521, 'title': 'Challenge Answer', 'type': 'supergroup'}, 'date': 1665595298, 'edit_date': 1665595466, 'text': '😂Sewa samapt! 😂 🚨Encountered an error. Someone sent an unreadable file in private chat to bot for which it was not prepared! People kept experimenting! Will require sometime to fix the error. Till then you may use only text format to interact with bot. It will ignore images from now. \nFor any questions just type #matchQ<question number> and copy the format. Edit the digits and send with #solveQ<question number> .', 'entities': [{'offset': 317, 'length': 7, 'type': 'hashtag'}, {'offset': 393, 'length': 7, 'type': 'hashtag'}]}}]}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': [{'update_id': 182987379, 'message': {'message_id': 5200, 'from': {'id': 5538022478, 'is_bot': False, 'first_name': 'Himanshu', 'username': 'Himanshusainiraj'}, 'chat': {'id': -1001636347521, 'title': 'Challenge Answer', 'type': 'supergroup'}, 'date': 1665595481, 'text': '#matchQ4', 'entities': [{'offset': 0, 'length': 8, 'type': 'hashtag'}]}}]}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': [{'update_id': 182987380, 'message': {'message_id': 5202, 'from': {'id': 1337180804, 'is_bot': False, 'first_name': 'Ketan', 'last_name': 'Yadav'}, 'chat': {'id': -1001636347521, 'title': 'Challenge Answer', 'type': 'supergroup'}, 'date': 1665595611, 'text': '[In reply to ketan]\nHere it is : \nJay bought a new car in New York where a license plate can be created with alphabets A, B, C, D, E, W, X, Y, Z and numbers 0 to 9. He can either select a normal license plate or a VIP license plate. The VIP license plate begins with 3 alphabets followed by 3 numbers with repetition allowed. The normal license plate begins with 1 numbers followed by 3  alphabets without repetition.In how many ways can he select VIP license plate?  \n\nPlease copy the message as it is and just replace the values according to your question #solveQ4 \n\nAnswer Matching? Thumbs up! or Not Matching? Thumbs down!', 'entities': [{'offset': 558, 'length': 8, 'type': 'hashtag'}]}}]}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': [{'update_id': 182987381, 'message': {'message_id': 5204, 'from': {'id': 2009150623, 'is_bot': False, 'first_name': 'Cricketer', 'last_name': 'Aman'}, 'chat': {'id': -1001636347521, 'title': 'Challenge Answer', 'type': 'supergroup'}, 'date': 1665595680, 'text': 'Jay bought a new car in New York where a license plate can be created with alphabets A, B, C, D, E, W, X, Y, Z and numbers 0 to 9. He can either select a normal license plate or a VIP license plate. The VIP license plate begins with 2 alphabets followed by 4 numbers with repetition allowed. The normal license plate begins with 2 numbers followed by 3 alphabets without repetition.In how many ways can he select VIP license plate?\xa0 \n #solveQ4', 'entities': [{'offset': 435, 'length': 8, 'type': 'hashtag'}]}}]}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': [{'update_id': 182987382, 'message': {'message_id': 5206, 'from': {'id': 867068034, 'is_bot': False, 'first_name': 'Preet', 'last_name': 'Patel'}, 'chat': {'id': -1001636347521, 'title': 'Challenge Answer', 'type': 'supergroup'}, 'date': 1665595686, 'text': 'Jay bought a new car in New York where a license plate can be created with alphabets A, B, C, D, E, W, X, Y, Z and numbers 0 to 9. He can either select a normal license plate or a VIP license plate. The VIP license plate begins with 3 alphabets followed by 3 numbers with repetition allowed. The normal license plate begins with 1 numbers followed by 3 alphabets without repetition.In how many ways can he select the license plate(normal or VIP)?'}}]}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': [{'update_id': 182987383, 'message': {'message_id': 5207, 'from': {'id': 5676856946, 'is_bot': False, 'first_name': 'Munna bhaiya', 'last_name': 'King of mirzapur'}, 'chat': {'id': -1001636347521, 'title': 'Challenge Answer', 'type': 'supergroup'}, 'date': 1665595695, 'photo': [{'file_id': 'AgACAgUAAx0CYYiugQACFFdjRvkv0sv9RqXTPTkseYsmgZ6yXgACMrExGx_xOFZA2CbqljtxaQEAAwIAA3MAAyoE', 'file_unique_id': 'AQADMrExGx_xOFZ4', 'file_size': 400, 'width': 90, 'height': 15}, {'file_id': 'AgACAgUAAx0CYYiugQACFFdjRvkv0sv9RqXTPTkseYsmgZ6yXgACMrExGx_xOFZA2CbqljtxaQEAAwIAA20AAyoE', 'file_unique_id': 'AQADMrExGx_xOFZy', 'file_size': 3526, 'width': 320, 'height': 54}, {'file_id': 'AgACAgUAAx0CYYiugQACFFdjRvkv0sv9RqXTPTkseYsmgZ6yXgACMrExGx_xOFZA2CbqljtxaQEAAwIAA3gAAyoE', 'file_unique_id': 'AQADMrExGx_xOFZ9', 'file_size': 15396, 'width': 800, 'height': 135}, {'file_id': 'AgACAgUAAx0CYYiugQACFFdjRvkv0sv9RqXTPTkseYsmgZ6yXgACMrExGx_xOFZA2CbqljtxaQEAAwIAA3kAAyoE', 'file_unique_id': 'AQADMrExGx_xOFZ-', 'file_size': 19001, 'width': 960, 'height': 162}]}}]}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': [{'update_id': 182987384, 'message': {'message_id': 5208, 'from': {'id': 1337180804, 'is_bot': False, 'first_name': 'Ketan', 'last_name': 'Yadav'}, 'chat': {'id': -1001636347521, 'title': 'Challenge Answer', 'type': 'supergroup'}, 'date': 1665595740, 'text': '[In reply to Ketan Yadav]\nHere it is : \n7 classmates could not agree on who would stand in the group photo along with the teacher for the yearbook. How many possible groups can be made such that there is at least one student with the teacher in the photo?\n\nAnswer Matching? Thumbs up! or Not Matching? Thumbs down!'}}]}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': [{'update_id': 182987385, 'message': {'message_id': 5209, 'from': {'id': 2009150623, 'is_bot': False, 'first_name': 'Cricketer', 'last_name': 'Aman'}, 'chat': {'id': -1001636347521, 'title': 'Challenge Answer', 'type': 'supergroup'}, 'date': 1665595778, 'text': '#matchQ3', 'entities': [{'offset': 0, 'length': 8, 'type': 'hashtag'}]}}]}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': [{'update_id': 182987386, 'message': {'message_id': 5211, 'from': {'id': 867068034, 'is_bot': False, 'first_name': 'Preet', 'last_name': 'Patel'}, 'chat': {'id': -1001636347521, 'title': 'Challenge Answer', 'type': 'supergroup'}, 'date': 1665595829, 'text': 'Jay bought a new car in New York where a license plate can be created with alphabets A, B, C, D, E, W, X, Y, Z and numbers 0 to 9. He can either select a normal license plate or a VIP license plate. The VIP license plate begins with 3 alphabets followed by 3 numbers with repetition allowed. The normal license plate begins with 1 numbers followed by 3 alphabets without repetition.In how many ways can he select the license plate(normal or VIP)?\n#solveQ4', 'entities': [{'offset': 447, 'length': 8, 'type': 'hashtag'}]}}]}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': [{'update_id': 182987387, 'message': {'message_id': 5213, 'from': {'id': 5538022478, 'is_bot': False, 'first_name': 'Himanshu', 'username': 'Himanshusainiraj'}, 'chat': {'id': -1001636347521, 'title': 'Challenge Answer', 'type': 'supergroup'}, 'date': 1665595833, 'text': 'Jay bought a new car in New York where a license plate can be created with alphabets A, B, C, D, E, W, X, Y, Z and numbers 0 to 9. He can either select a normal license plate or a VIP license plate. The VIP license plate begins with 1 alphabets followed by 4 numbers with repetition allowed. The normal license plate begins with 1 numbers followed by 4 alphabets without repetition.In how many ways can he select VIP license plate?   \n \n#solveQ4', 'entities': [{'offset': 437, 'length': 8, 'type': 'hashtag'}]}}]}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': [{'update_id': 182987388, 'message': {'message_id': 5215, 'from': {'id': 1942363985, 'is_bot': False, 'first_name': 'Palak', 'last_name': 'Shori'}, 'chat': {'id': -1001636347521, 'title': 'Challenge Answer', 'type': 'supergroup'}, 'date': 1665595866, 'text': 'Ram has n trophies that he wishes to place in his main cabinet, which has space only for two trophies. If the number of trophies is increased by 3, then the number of possible ways to arrange the trophies in the main cabinet becomes 5 times the number of ways to arrange n trophies. How many trophies does Ram have?  #solveQ5', 'entities': [{'offset': 317, 'length': 8, 'type': 'hashtag'}]}}]}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': [{'update_id': 182987389, 'message': {'message_id': 5217, 'from': {'id': 2009150623, 'is_bot': False, 'first_name': 'Cricketer', 'last_name': 'Aman'}, 'chat': {'id': -1001636347521, 'title': 'Challenge Answer', 'type': 'supergroup'}, 'date': 1665595903, 'text': 'Jay bought a new car in New York where a license plate can be created with alphabets A, B, C, D, E, W, X, Y, Z and numbers 0 to 9. He can either select a normal license plate or a VIP license plate. The VIP license plate begins with 2 alphabets followed by 4 numbers with repetition allowed. The normal license plate begins with 2 numbers followed by 3 alphabets without repetition.In how many ways can he select VIP license plate?\n #solveQ3', 'entities': [{'offset': 433, 'length': 8, 'type': 'hashtag'}]}}]}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': [{'update_id': 182987390, 'message': {'message_id': 5219, 'from': {'id': 867068034, 'is_bot': False, 'first_name': 'Preet', 'last_name': 'Patel'}, 'chat': {'id': -1001636347521, 'title': 'Challenge Answer', 'type': 'supergroup'}, 'date': 1665595906, 'text': 'Ram has nn trophies that he wishes to place in his main cabinet, which has space only for two trophies. If the number of trophies is increased by 3, then the number of possible ways to arrange the trophies in the main cabinet becomes 5 times the number of ways to arrange nn trophies. How many trophies does Ram have #solveQ5', 'entities': [{'offset': 317, 'length': 8, 'type': 'hashtag'}]}}]}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': [{'update_id': 182987391, 'message': {'message_id': 5221, 'from': {'id': 5538022478, 'is_bot': False, 'first_name': 'Himanshu', 'username': 'Himanshusainiraj'}, 'chat': {'id': -1001636347521, 'title': 'Challenge Answer', 'type': 'supergroup'}, 'date': 1665595936, 'text': '#matchQ3', 'entities': [{'offset': 0, 'length': 8, 'type': 'hashtag'}]}}]}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': [{'update_id': 182987392, 'message': {'message_id': 59, 'from': {'id': 1337180804, 'is_bot': False, 'first_name': 'Ketan', 'last_name': 'Yadav', 'language_code': 'en'}, 'chat': {'id': 1337180804, 'first_name': 'Ketan', 'last_name': 'Yadav', 'type': 'private'}, 'date': 1665595959, 'text': '/start', 'entities': [{'offset': 0, 'length': 6, 'type': 'bot_command'}]}}]}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': [{'update_id': 182987393, 'message': {'message_id': 5223, 'from': {'id': 5538022478, 'is_bot': False, 'first_name': 'Himanshu', 'username': 'Himanshusainiraj'}, 'chat': {'id': -1001636347521, 'title': 'Challenge Answer', 'type': 'supergroup'}, 'date': 1665595961, 'text': 'Jay bought a new car in New York where a license plate can be created with alphabets A, B, C, D, E, W, X, Y, Z and numbers 0 to 9. He can either select a normal license plate or a VIP license plate. The VIP license plate begins with 1 alphabets followed by 2 numbers with repetition allowed. The normal license plate begins with 1 numbers followed by 2 alphabets without repetition.In how many ways can he select VIP license plate?'}}]}
# {'ok': True, 'result': [{'update_id': 182987394, 'message': {'message_id': 5224, 'from': {'id': 2009150623, 'is_bot': False, 'first_name': 'Cricketer', 'last_name': 'Aman'}, 'chat': {'id': -1001636347521, 'title': 'Challenge Answer', 'type': 'supergroup'}, 'date': 1665595962, 'text': '#matchQ1', 'entities': [{'offset': 0, 'length': 8, 'type': 'hashtag'}]}}]}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': [{'update_id': 182987395, 'message': {'message_id': 5226, 'from': {'id': 867068034, 'is_bot': False, 'first_name': 'Preet', 'last_name': 'Patel'}, 'chat': {'id': -1001636347521, 'title': 'Challenge Answer', 'type': 'supergroup'}, 'date': 1665595987, 'text': '#solveQ5', 'entities': [{'offset': 0, 'length': 8, 'type': 'hashtag'}]}}]}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': [{'update_id': 182987396, 'message': {'message_id': 60, 'from': {'id': 1337180804, 'is_bot': False, 'first_name': 'Ketan', 'last_name': 'Yadav', 'language_code': 'en'}, 'chat': {'id': 1337180804, 'first_name': 'Ketan', 'last_name': 'Yadav', 'type': 'private'}, 'date': 1665595996, 'text': '[In reply to Ketan Yadav]\nHere it is : \n7 classmates could not agree on who would stand in the group photo along with the teacher for the yearbook. How many possible groups can be made such that there is at least one student with the teacher in the photo?\n\nAnswer Matching? Thumbs up! or Not Matching? Thumbs down!'}}]}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': [{'update_id': 182987397, 'message': {'message_id': 5228, 'from': {'id': 1942363985, 'is_bot': False, 'first_name': 'Palak', 'last_name': 'Shori'}, 'chat': {'id': -1001636347521, 'title': 'Challenge Answer', 'type': 'supergroup'}, 'date': 1665596003, 'text': '2 students watched a patriotic movie. An analyst wishes to ask each student whether they liked the movie or not. Each student can either answer the question or refuse to respond. In how many ways, can the analyst get responses from the students? #solveQ7', 'entities': [{'offset': 246, 'length': 8, 'type': 'hashtag'}]}}]}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': [{'update_id': 182987398, 'message': {'message_id': 5230, 'from': {'id': 1114157697, 'is_bot': False, 'first_name': 'Dinesh', 'last_name': 'A', 'username': 'adinesh590'}, 'chat': {'id': -1001636347521, 'title': 'Challenge Answer', 'type': 'supergroup'}, 'date': 1665596007, 'text': 'Vinod has 3 registers and 6 cover papers of different colours. In how many ways can he cover all the registers with cover papers?\n#solveQ1', 'entities': [{'offset': 130, 'length': 8, 'type': 'hashtag'}]}}]}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': [{'update_id': 182987399, 'message': {'message_id': 5232, 'from': {'id': 5538022478, 'is_bot': False, 'first_name': 'Himanshu', 'username': 'Himanshusainiraj'}, 'chat': {'id': -1001636347521, 'title': 'Challenge Answer', 'type': 'supergroup'}, 'date': 1665596013, 'text': 'Jay bought a new car in New York where a license plate can be created with alphabets A, B, C, D, E, W, X, Y, Z and numbers 0 to 9. He can either select a normal license plate or a VIP license plate. The VIP license plate begins with 1 alphabets followed by 4 numbers with repetition allowed. The normal license plate begins with 1 numbers followed by 4 alphabets without repetition.In how many ways can he select VIP license plate?   \n \n#solveQ3', 'entities': [{'offset': 437, 'length': 8, 'type': 'hashtag'}]}}]}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': [{'update_id': 182987400, 'message': {'message_id': 5234, 'from': {'id': 1114157697, 'is_bot': False, 'first_name': 'Dinesh', 'last_name': 'A', 'username': 'adinesh590'}, 'chat': {'id': -1001636347521, 'title': 'Challenge Answer', 'type': 'supergroup'}, 'date': 1665596051, 'text': '7 classmates could not agree on who would stand in the group photo along with the teacher for the yearbook. How many possible groups can be made such that there is at least one student with the teacher in the photo?\n#solveQ2', 'entities': [{'offset': 216, 'length': 8, 'type': 'hashtag'}]}}]}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': [{'update_id': 182987401, 'message': {'message_id': 5236, 'from': {'id': 1337180804, 'is_bot': False, 'first_name': 'Ketan', 'last_name': 'Yadav', 'language_code': 'en'}, 'chat': {'id': -1001636347521, 'title': 'Challenge Answer', 'type': 'supergroup'}, 'date': 1665596062, 'text': 'Vinod has 4 registers and 6 cover papers of different colours. In how many ways can he cover all the registers with cover papers?\n#SolveQ1', 'entities': [{'offset': 130, 'length': 8, 'type': 'hashtag'}]}}]}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': [{'update_id': 182987402, 'message': {'message_id': 5237, 'from': {'id': 1114157697, 'is_bot': False, 'first_name': 'Dinesh', 'last_name': 'A', 'username': 'adinesh590'}, 'chat': {'id': -1001636347521, 'title': 'Challenge Answer', 'type': 'supergroup'}, 'date': 1665596090, 'text': 'Jay bought a new car in New York where a license plate can be created with alphabets A, B, C, D, E, W, X, Y, Z and numbers 0 to 9. He can either select a normal license plate or a VIP license plate. The VIP license plate begins with 3 alphabets followed by 3 numbers with repetition allowed. The normal license plate begins with 1 numbers followed by 3 alphabets without repetition.In how many ways can he select VIP license plate?\n#solveQ3', 'entities': [{'offset': 432, 'length': 8, 'type': 'hashtag'}]}}]}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': [{'update_id': 182987403, 'message': {'message_id': 5239, 'from': {'id': 1114157697, 'is_bot': False, 'first_name': 'Dinesh', 'last_name': 'A', 'username': 'adinesh590'}, 'chat': {'id': -1001636347521, 'title': 'Challenge Answer', 'type': 'supergroup'}, 'date': 1665596126, 'text': 'Jay bought a new car in New York where a license plate can be created with alphabets A, B, C, D, E, W, X, Y, Z and numbers 0 to 9. He can either select a normal license plate or a VIP license plate. The VIP license plate begins with 3 alphabets followed by 3 numbers with repetition allowed. The normal license plate begins with 1 numbers followed by 3 alphabets without repetition.In how many ways can he select the license plate(normal or VIP)?\n#solveQ4', 'entities': [{'offset': 447, 'length': 8, 'type': 'hashtag'}]}}]}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': [{'update_id': 182987404, 'message': {'message_id': 5241, 'from': {'id': 5538022478, 'is_bot': False, 'first_name': 'Himanshu', 'username': 'Himanshusainiraj'}, 'chat': {'id': -1001636347521, 'title': 'Challenge Answer', 'type': 'supergroup'}, 'date': 1665596152, 'text': '#matchQ1', 'entities': [{'offset': 0, 'length': 8, 'type': 'hashtag'}]}}]}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': [{'update_id': 182987405, 'message': {'message_id': 5243, 'from': {'id': 1114157697, 'is_bot': False, 'first_name': 'Dinesh', 'last_name': 'A', 'username': 'adinesh590'}, 'chat': {'id': -1001636347521, 'title': 'Challenge Answer', 'type': 'supergroup'}, 'date': 1665596155, 'text': 'Ram has nn trophies that he wishes to place in his main cabinet, which has space only for two trophies. If the number of trophies is increased by 3, then the number of possible ways to arrange the trophies in the main cabinet becomes 5 times the number of ways to arrange nn trophies. How many trophies does Ram have?\n#solveQ5', 'entities': [{'offset': 318, 'length': 8, 'type': 'hashtag'}]}}]}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': [{'update_id': 182987406, 'message': {'message_id': 5245, 'from': {'id': 1938038415, 'is_bot': False, 'first_name': 'Yash'}, 'chat': {'id': -1001636347521, 'title': 'Challenge Answer', 'type': 'supergroup'}, 'date': 1665596184, 'photo': [{'file_id': 'AgACAgUAAx0CYYiugQACFH1jRvsYFK0Wm-MTwLe1WZhSjiqq3gACSLMxG30yOVbwSsawTbel4wEAAwIAA3MAAyoE', 'file_unique_id': 'AQADSLMxG30yOVZ4', 'file_size': 510, 'width': 90, 'height': 20}, {'file_id': 'AgACAgUAAx0CYYiugQACFH1jRvsYFK0Wm-MTwLe1WZhSjiqq3gACSLMxG30yOVbwSsawTbel4wEAAwIAA20AAyoE', 'file_unique_id': 'AQADSLMxG30yOVZy', 'file_size': 6876, 'width': 320, 'height': 71}, {'file_id': 'AgACAgUAAx0CYYiugQACFH1jRvsYFK0Wm-MTwLe1WZhSjiqq3gACSLMxG30yOVbwSsawTbel4wEAAwIAA3gAAyoE', 'file_unique_id': 'AQADSLMxG30yOVZ9', 'file_size': 34043, 'width': 800, 'height': 177}, {'file_id': 'AgACAgUAAx0CYYiugQACFH1jRvsYFK0Wm-MTwLe1WZhSjiqq3gACSLMxG30yOVbwSsawTbel4wEAAwIAA3kAAyoE', 'file_unique_id': 'AQADSLMxG30yOVZ-', 'file_size': 63624, 'width': 1280, 'height': 284}]}}]}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': [{'update_id': 182987407, 'message': {'message_id': 5246, 'from': {'id': 5538022478, 'is_bot': False, 'first_name': 'Himanshu', 'username': 'Himanshusainiraj'}, 'chat': {'id': -1001636347521, 'title': 'Challenge Answer', 'type': 'supergroup'}, 'date': 1665596186, 'text': 'Vinod has 3 registers and 9 cover papers of different colours. In how many ways can he cover all the registers with cover papers?   \n \nPlease copy the message as it is and just replace the values according to your question #solveQ1', 'entities': [{'offset': 223, 'length': 8, 'type': 'hashtag'}]}}]}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': [{'update_id': 182987408, 'message': {'message_id': 5248, 'from': {'id': 1977474604, 'is_bot': False, 'first_name': 'Suyash', 'username': 'NERDY_GUY13'}, 'chat': {'id': -1001636347521, 'title': 'Challenge Answer', 'type': 'supergroup'}, 'date': 1665596192, 'text': 'Vinod has 4 registers and 6 cover papers of different colours. In how many ways can he cover all the registers with cover papers? #matchq1', 'entities': [{'offset': 130, 'length': 8, 'type': 'hashtag'}]}}]}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': [{'update_id': 182987409, 'message': {'message_id': 5249, 'from': {'id': 1383674280, 'is_bot': False, 'first_name': 'M', 'last_name': 'Amanullah', 'username': 'killer_silent07'}, 'chat': {'id': -1001636347521, 'title': 'Challenge Answer', 'type': 'supergroup'}, 'date': 1665596200, 'new_chat_participant': {'id': 1383674280, 'is_bot': False, 'first_name': 'M', 'last_name': 'Amanullah', 'username': 'killer_silent07'}, 'new_chat_member': {'id': 1383674280, 'is_bot': False, 'first_name': 'M', 'last_name': 'Amanullah', 'username': 'killer_silent07'}, 'new_chat_members': [{'id': 1383674280, 'is_bot': False, 'first_name': 'M', 'last_name': 'Amanullah', 'username': 'killer_silent07'}]}}]}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': [{'update_id': 182987410, 'edited_message': {'message_id': 5243, 'from': {'id': 1114157697, 'is_bot': False, 'first_name': 'Dinesh', 'last_name': 'A', 'username': 'adinesh590'}, 'chat': {'id': -1001636347521, 'title': 'Challenge Answer', 'type': 'supergroup'}, 'date': 1665596155, 'edit_date': 1665596222, 'text': 'Ram has n trophies that he wishes to place in his main cabinet, which has space only for two trophies. If the number of trophies is increased by 3, then the number of possible ways to arrange the trophies in the main cabinet becomes 5 times the number of ways to arrange n trophies. How many trophies does Ram have?\n#solveQ5', 'entities': [{'offset': 316, 'length': 8, 'type': 'hashtag'}]}}]}
# {'ok': True, 'result': []}
# {'ok': True, 'result': [{'update_id': 182987411, 'message': {'message_id': 5250, 'from': {'id': 5538022478, 'is_bot': False, 'first_name': 'Himanshu', 'username': 'Himanshusainiraj'}, 'chat': {'id': -1001636347521, 'title': 'Challenge Answer', 'type': 'supergroup'}, 'date': 1665596223, 'text': 'Vinod has 4 registers and 6 cover papers of different colours. In how many ways can he cover all the registers with cover papers?   \n \nPlease copy the message as it is and just replace the values according to your question #solveQ1', 'entities': [{'offset': 223, 'length': 8, 'type': 'hashtag'}]}}]}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': [{'update_id': 182987412, 'message': {'message_id': 5252, 'from': {'id': 1114157697, 'is_bot': False, 'first_name': 'Dinesh', 'last_name': 'A', 'username': 'adinesh590'}, 'chat': {'id': -1001636347521, 'title': 'Challenge Answer', 'type': 'supergroup'}, 'date': 1665596231, 'text': 'Ram has n trophies that he wishes to place in his main cabinet, which has space only for two trophies. If the number of trophies is increased by 3, then the number of possible ways to arrange the trophies in the main cabinet becomes 5 times the number of ways to arrange n trophies. How many trophies does Ram have?\n#solveQ5', 'entities': [{'offset': 316, 'length': 8, 'type': 'hashtag'}]}}]}
# {'ok': True, 'result': []}
# {'ok': True, 'result': [{'update_id': 182987413, 'message': {'message_id': 5254, 'from': {'id': 1977474604, 'is_bot': False, 'first_name': 'Suyash', 'username': 'NERDY_GUY13'}, 'chat': {'id': -1001636347521, 'title': 'Challenge Answer', 'type': 'supergroup'}, 'date': 1665596234, 'text': 'Vinod has 4 registers and 6 cover papers of different colours. In how many ways can he cover all the registers with cover papers? #matchq1', 'entities': [{'offset': 130, 'length': 8, 'type': 'hashtag'}]}}]}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': [{'update_id': 182987414, 'message': {'message_id': 5255, 'from': {'id': 1938038415, 'is_bot': False, 'first_name': 'Yash'}, 'chat': {'id': -1001636347521, 'title': 'Challenge Answer', 'type': 'supergroup'}, 'date': 1665596254, 'text': 'Jay bought a new car in New York where a license plate can be created with alphabets A, B, C, D, E, W, X, Y, Z and numbers 0 to 9. He can either select a normal license plate or a VIP license plate. The VIP license plate begins with 1 alphabets followed by 2 numbers with repetition allowed. The normal license plate begins with 1 numbers followed by 2 alphabets without repetition.In how many ways can he select the license plate(normal or VIP)?'}}]}
# {'ok': True, 'result': [{'update_id': 182987415, 'message': {'message_id': 5256, 'from': {'id': 5538022478, 'is_bot': False, 'first_name': 'Himanshu', 'username': 'Himanshusainiraj'}, 'chat': {'id': -1001636347521, 'title': 'Challenge Answer', 'type': 'supergroup'}, 'date': 1665596255, 'text': '#matchQ2', 'entities': [{'offset': 0, 'length': 8, 'type': 'hashtag'}]}}]}
# {'ok': True, 'result': []}
# {'ok': True, 'result': [{'update_id': 182987416, 'message': {'message_id': 5258, 'from': {'id': 2009150623, 'is_bot': False, 'first_name': 'Cricketer', 'last_name': 'Aman'}, 'chat': {'id': -1001636347521, 'title': 'Challenge Answer', 'type': 'supergroup'}, 'date': 1665596272, 'text': 'Vinod has 5 registers and 6 cover papers of different colours. In how many ways can he cover all the registers with cover papers? \n #solveQ1', 'entities': [{'offset': 132, 'length': 8, 'type': 'hashtag'}]}}]}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': [{'update_id': 182987417, 'message': {'message_id': 5260, 'from': {'id': 5538022478, 'is_bot': False, 'first_name': 'Himanshu', 'username': 'Himanshusainiraj'}, 'chat': {'id': -1001636347521, 'title': 'Challenge Answer', 'type': 'supergroup'}, 'date': 1665596280, 'text': '9 classmates could not agree on who would stand in the group photo along with the teacher for the yearbook. How many possible groups can be made such that there is at least one student with the teacher in the photo?   \n \nPlease copy the message as it is and just replace the values according to your question #solveQ2', 'entities': [{'offset': 309, 'length': 8, 'type': 'hashtag'}]}}]}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': [{'update_id': 182987418, 'message': {'message_id': 5262, 'from': {'id': 1114157697, 'is_bot': False, 'first_name': 'Dinesh', 'last_name': 'A', 'username': 'adinesh590'}, 'chat': {'id': -1001636347521, 'title': 'Challenge Answer', 'type': 'supergroup'}, 'date': 1665596284, 'text': 'Ram has n trophies that he wishes to place in his main cabinet, which has space only for two trophies. If the number of trophies is increased by 3, then the number of possible ways to arrange the trophies in the main cabinet becomes 5 times the number of ways to arrange n trophies. How many trophies does Ram have?\xa0 \n#solveQ5', 'entities': [{'offset': 318, 'length': 8, 'type': 'hashtag'}]}}]}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': [{'update_id': 182987419, 'message': {'message_id': 5264, 'from': {'id': 5538022478, 'is_bot': False, 'first_name': 'Himanshu', 'username': 'Himanshusainiraj'}, 'chat': {'id': -1001636347521, 'title': 'Challenge Answer', 'type': 'supergroup'}, 'date': 1665596295, 'text': '10 classmates could not agree on who would stand in the group photo along with the teacher for the yearbook. How many possible groups can be made such that there is at least one student with the teacher in the photo?   \n \nPlease copy the message as it is and just replace the values according to your question #solveQ2', 'entities': [{'offset': 310, 'length': 8, 'type': 'hashtag'}]}}]}
# {'ok': True, 'result': [{'update_id': 182987420, 'message': {'message_id': 5266, 'from': {'id': 1977474604, 'is_bot': False, 'first_name': 'Suyash', 'username': 'NERDY_GUY13'}, 'chat': {'id': -1001636347521, 'title': 'Challenge Answer', 'type': 'supergroup'}, 'date': 1665596296, 'text': '#solveQ2', 'entities': [{'offset': 0, 'length': 8, 'type': 'hashtag'}]}}]}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': [{'update_id': 182987421, 'message': {'message_id': 5268, 'from': {'id': 1114157697, 'is_bot': False, 'first_name': 'Dinesh', 'last_name': 'A', 'username': 'adinesh590'}, 'chat': {'id': -1001636347521, 'title': 'Challenge Answer', 'type': 'supergroup'}, 'date': 1665596309, 'text': 'There are 30 students in a class. The class teacher announced that the first 4 students who completes a given project within two days will be awarded. What are the possible number of ways the students will be awarded?\n#solveQ6', 'entities': [{'offset': 218, 'length': 8, 'type': 'hashtag'}]}}]}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': [{'update_id': 182987422, 'message': {'message_id': 5270, 'from': {'id': 1977474604, 'is_bot': False, 'first_name': 'Suyash', 'username': 'NERDY_GUY13'}, 'chat': {'id': -1001636347521, 'title': 'Challenge Answer', 'type': 'supergroup'}, 'date': 1665596335, 'text': '6 classmates could not agree on who would stand in the group photo along with the teacher for the yearbook. How many possible groups can be made such that there is at least one student with the teacher in the photo?\n#solveQ2', 'entities': [{'offset': 216, 'length': 8, 'type': 'hashtag'}]}}]}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': [{'update_id': 182987423, 'message': {'message_id': 5272, 'from': {'id': 5538022478, 'is_bot': False, 'first_name': 'Himanshu', 'username': 'Himanshusainiraj'}, 'chat': {'id': -1001636347521, 'title': 'Challenge Answer', 'type': 'supergroup'}, 'date': 1665596346, 'text': 'Jay bought a new car in New York where a license plate can be created with alphabets A, B, C, D, E, W, X, Y, Z and numbers 0 to 9. He can either select a normal license plate or a VIP license plate. The VIP license plate begins with 2 alphabets followed by 3 numbers with repetition allowed. The normal license plate begins with 2 numbers followed by 3 alphabets without repetition.In how many ways can he select VIP license plate?   \n \nPlease copy the message as it is and just replace the values according to your question #solveQ3', 'entities': [{'offset': 525, 'length': 8, 'type': 'hashtag'}]}}]}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': [{'update_id': 182987424, 'message': {'message_id': 5274, 'from': {'id': 2009150623, 'is_bot': False, 'first_name': 'Cricketer', 'last_name': 'Aman'}, 'chat': {'id': -1001636347521, 'title': 'Challenge Answer', 'type': 'supergroup'}, 'date': 1665596372, 'text': '6 classmates could not agree on who would stand in the group photo along with the teacher for the yearbook. How many possible groups can be made such that there is at least one student with the teacher in the photo?\xa0 \n #solveQ2', 'entities': [{'offset': 219, 'length': 8, 'type': 'hashtag'}]}}]}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': [{'update_id': 182987425, 'message': {'message_id': 5276, 'from': {'id': 1383674280, 'is_bot': False, 'first_name': 'M', 'last_name': 'Amanullah', 'username': 'killer_silent07'}, 'chat': {'id': -1001636347521, 'title': 'Challenge Answer', 'type': 'supergroup'}, 'date': 1665596376, 'text': 'Vinod has 5 registers and 6 cover papers of different colours. In how many ways can he cover all the registers with cover papers? \n #solveQ1', 'entities': [{'offset': 132, 'length': 8, 'type': 'hashtag'}]}}]}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# ...
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': [{'update_id': 182987609, 'message': {'message_id': 5565, 'from': {'id': 1272846589, 'is_bot': False, 'first_name': '𝓛𝓪𝓴𝓼𝓱𝔂𝓪 🔥', 'username': 'Laddu_iz_op'}, 'chat': {'id': -1001636347521, 'title': 'Challenge Answer', 'type': 'supergroup'}, 'date': 1665599143, 'text': '#matchQ6', 'entities': [{'offset': 0, 'length': 8, 'type': 'hashtag'}]}}]}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': [{'update_id': 182987610, 'message': {'message_id': 5567, 'from': {'id': 1272846589, 'is_bot': False, 'first_name': '𝓛𝓪𝓴𝓼𝓱𝔂𝓪 🔥', 'username': 'Laddu_iz_op'}, 'chat': {'id': -1001636347521, 'title': 'Challenge Answer', 'type': 'supergroup'}, 'date': 1665599170, 'text': 'There are 30 students in a class. The class teacher announced that the first  4 students who completes a given project within two days will be awarded. What are the possible number of ways the students will be awarded?  \n#solveQ6', 'entities': [{'offset': 221, 'length': 8, 'type': 'hashtag'}]}}]}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': [{'update_id': 182987611, 'message': {'message_id': 5569, 'from': {'id': 1272846589, 'is_bot': False, 'first_name': '𝓛𝓪𝓴𝓼𝓱𝔂𝓪 🔥', 'username': 'Laddu_iz_op'}, 'chat': {'id': -1001636347521, 'title': 'Challenge Answer', 'type': 'supergroup'}, 'date': 1665599216, 'text': '#matchQ8', 'entities': [{'offset': 0, 'length': 8, 'type': 'hashtag'}]}}]}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': [{'update_id': 182987612, 'message': {'message_id': 5571, 'from': {'id': 1272846589, 'is_bot': False, 'first_name': '𝓛𝓪𝓴𝓼𝓱𝔂𝓪 🔥', 'username': 'Laddu_iz_op'}, 'chat': {'id': -1001636347521, 'title': 'Challenge Answer', 'type': 'supergroup'}, 'date': 1665599243, 'text': '#matchQ7', 'entities': [{'offset': 0, 'length': 8, 'type': 'hashtag'}]}}]}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': [{'update_id': 182987613, 'message': {'message_id': 5573, 'from': {'id': 908481763, 'is_bot': False, 'first_name': 'tuku'}, 'chat': {'id': -1001636347521, 'title': 'Challenge Answer', 'type': 'supergroup'}, 'date': 1665599252, 'document': {'file_name': 'image_2022-10-12_23-57-31.png', 'mime_type': 'image/png', 'thumb': {'file_id': 'AAMCBQADHQJhiK6BAAIVxWNHBxStgVJv2U4ixXqWIeg8eSyEAAJOBwACH_E4VtSfEbBBrWeIAQAHbQADKgQ', 'file_unique_id': 'AQADTgcAAh_xOFZy', 'file_size': 9374, 'width': 320, 'height': 234}, 'file_id': 'BQACAgUAAx0CYYiugQACFcVjRwcUrYFSb9lOIsV6liHoPHkshAACTgcAAh_xOFbUnxGwQa1niCoE', 'file_unique_id': 'AgADTgcAAh_xOFY', 'file_size': 57698}}}]}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': [{'update_id': 182987614, 'message': {'message_id': 5574, 'from': {'id': 1272846589, 'is_bot': False, 'first_name': '𝓛𝓪𝓴𝓼𝓱𝔂𝓪 🔥', 'username': 'Laddu_iz_op'}, 'chat': {'id': -1001636347521, 'title': 'Challenge Answer', 'type': 'supergroup'}, 'date': 1665599261, 'text': '7 students watched a patriotic movie. An analyst wishes to ask each student whether they liked the movie or not. Each student can either answer the question or refuse to respond. In how many ways, can the analyst get responses from the students?  \n#SolveQ7', 'entities': [{'offset': 248, 'length': 8, 'type': 'hashtag'}]}}]}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': [{'update_id': 182987615, 'message': {'message_id': 5575, 'from': {'id': 1272846589, 'is_bot': False, 'first_name': '𝓛𝓪𝓴𝓼𝓱𝔂𝓪 🔥', 'username': 'Laddu_iz_op'}, 'chat': {'id': -1001636347521, 'title': 'Challenge Answer', 'type': 'supergroup'}, 'date': 1665599294, 'text': '8 students watched a patriotic movie. An analyst wishes to ask each student whether they liked the movie or not. Each student can either answer the question or refuse to respond. In how many ways, can the analyst get responses from the students?  \n#solveQ7', 'entities': [{'offset': 248, 'length': 8, 'type': 'hashtag'}]}}]}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# {'ok': True, 'result': []}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     478                         # For Python 2.7, use buffering of HTTP responses
# --> 479                         r = low_conn.getresponse(buffering=True)
#     480                     except TypeError:
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-82-08da98de0ef9> in <module>
#     280 while True:
#     281
# --> 282   offset = read_msg(offset)
#
# <ipython-input-82-08da98de0ef9> in read_msg(offset)
#      20   }
#      21
# ---> 22   resp = requests.get(base_url + "/getUpdates", data = parameters)
#      23
#      24   data = resp.json()
#
# /usr/local/lib/python3.7/dist-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# /usr/local/lib/python3.7/dist-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# /usr/local/lib/python3.7/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# /usr/local/lib/python3.7/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.7/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     480                     except TypeError:
#     481                         # For compatibility with Python 3.3+
# --> 482                         r = low_conn.getresponse()
#     483
#     484                     resp = HTTPResponse.from_httplib(
#
# /usr/lib/python3.7/http/client.py in getresponse(self)
#    1371         try:
#    1372             try:
# -> 1373                 response.begin()
#    1374             except ConnectionError:
#    1375                 self.close()
#
# /usr/lib/python3.7/http/client.py in begin(self)
#     317         # read until we get a non-100 response
#     318         while True:
# --> 319             version, status, reason = self._read_status()
#     320             if status != CONTINUE:
#     321                 break
#
# /usr/lib/python3.7/http/client.py in _read_status(self)
#     278
#     279     def _read_status(self):
# --> 280         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     281         if len(line) > _MAXLINE:
#     282             raise LineTooLong("status line")
#
# /usr/lib/python3.7/socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# /usr/lib/python3.7/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1069                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1070                   self.__class__)
# -> 1071             return self.read(nbytes, buffer)
#    1072         else:
#    1073             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.7/ssl.py in read(self, len, buffer)
#     927         try:
#     928             if buffer is not None:
# --> 929                 return self._sslobj.read(len, buffer)
#     930             else:
#     931                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
ques = 'Let x = factorial(5)/4 x 3!.Which of the following expressions is/are equal to x?'
re.findall("[2-9]",ques)
# Out:
# ['5', '4', '3']
